# %%
import requests
import pandas as pd

# %%
url = 'https://www.indexmundi.com/map/?t=0&v=35&r=xx&l=en'
html = requests.get(url).content
vih = pd.read_html(html)[2]

# %%
vih
# Out:
#                                Country  HIV/AIDS - people living with HIV/AIDS  Year
# 0                         South Africa                                 7100000  2018
# 1                              Nigeria                                 3200000  2018
# 2                                India                                 2100000  2018
# 3                           Mozambique                                 1800000  2018
# 4                                Kenya                                 1600000  2018
# 5                             Tanzania                                 1400000  2018
# 6                               Uganda                                 1400000  2018
# 7                             Zimbabwe                                 1300000  2018
# 8                               Zambia                                 1200000  2018
# 9                               Malawi                                 1000000  2018
# ...

# %% [markdown]
# # TIPOS DE DATOS
#
# ## Country:
# No existe jerarquía entre países para colocar a uno encima de otro (categórica)
#
# ## People living with HIV/AIDS:
# A simple vista, puede parecer una cantidad cuantitativa, pero para análisis de datos, no lo sería, dado que no tiene unidades (categórica ordinal)
#
# ## Year:
# Lo mismo que con *People living with HIV/AIDS* (categórica)

# %% [markdown]
# # Preguntas
#
# ## Sueldos:
#
# - ¿Cuál es el porcentaje del sueldo neto destinado a cada subsección de la tabla (Cuotas de seguridad social, previsión social, ayuda por servicios, apoyo familiar, etc.) para, por ejemplo, un trabajador en el nivel 18?
# - ¿Cuál es el sueldo base promedio de un trabajador en esta dependencia (independientemente de su cargo en la institución u otros factores)
# - ¿Cuál es el nivel con más cargos?
# - En total, ¿cuánto dinero se destina a los sueldos de estas personas (suponiendo que solo existe una persona en cada cargo)?
# - ¿De cuánto dinero es la diferencia entre el sueldo neto mayor (gobernador del estado) y el sueldo de otros empleados (por ejemplo, alguien de nivel 1, que es el nivel más bajo en la tabla)?
# - De todos las diferentes subsecciones del sueldo (Cuotas de seguridad social, previsión social, ayuda por servicios, apoyo familiar, etc.), ¿a cuál se le destina más dinero por sobre de los demás?
# - De todos las diferentes subsecciones del sueldo (Cuotas de seguridad social, previsión social, ayuda por servicios, apoyo familiar, etc.), ¿a cuál se le destina menos dinero por sobre de los demás?
# - Comparando niveles, ¿existe algún parámetro en el que el dinero destinado sea mayor para una persona de nivel, digamos, 2, comparado con el de una persona de nivel 3?
# - En los niveles más bajos, existen subsecciones entre cargos similares (por ejemplo, en los niveles uno, dos y tres, se hallan operadores/as técnicos/as tipo D, C, B y A), ¿cuáles son las principales diferencias entre los sueldos de estas personas?
#
# ## Clima:
# - En el caso de lluvias, ¿cómo puedo saber cuál es el estado con mayor precipitación (o cuál tiene la menor) en base a los datos proporcionados?
# - ¿Cuáles son los estados con mayor número de mediciones (centros de medición)?
# - ¿Cómo es la diferencia entre temperatura media, máxima y mínima para cada estado?
# - ¿Cuáles son los estados con la precipitación más alta en determinado mes/año?
# - ¿Cuáles son los estados con la temperatura más alta en determinado mes/año?
